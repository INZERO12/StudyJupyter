# %%
import pandas as pd

# %%
drama_tot = pd.read_csv('./df_drama_kor_all_tot2.csv')

# %%
drama_tot.head()
# Out:
#        방송일자   채널명  프로그램시작시간  프로그램종료시간      프로그램명 방송회차명 프로그램장르소분류명  \
# 0  20200101  KBS2        22    222624     99억의여자   17회      미니시리즈
# 1  20200101  KBS2        22    230803     99억의여자   18회      미니시리즈
# 2  20200101   MBC        21    220027    하자있는인간들   22회      미니시리즈
# 3  20200101   tvN        21    224540  싸이코패스다이어리   13회      미니시리즈
# 4  20200102  KBS2        22    222920     99억의여자   19회      미니시리즈
#
#                    출연진내용      총시청률
# 0  ['조여정', '김강우', '정웅인']  4.117441
# 1  ['조여정', '김강우', '정웅인']  5.312815
# 2  ['오연서', '안재현', '김슬기']  1.505145
# 3  ['윤시윤', '정인선', '박성훈']  1.390483
# 4  ['조여정', '김강우', '정웅인']  3.286444

# %%
len(drama_tot)
# Out:
# 2095

# %%
# # 같은 방송, 같은 회차일시, 최근 방송순만 필터링
# temp1 = []
# temp2 = []
# temp3 = []
# ct1 = []
# ct2 = []
# ct3 = []
# day1 = []
# day2 = []
# day3 = []

# for i in range(0, len(drama_tot)):
#     temp1.append(drama_tot["프로그램명"][i])
#     ct1.append(drama_tot["방송회차명"][i])
#     day1.append(drama_tot["방송일자"][i])
#     for j in range(0, len(drama_tot)):
#         temp2.append(drama_tot["프로그램명"][j])
#         ct2.append(drama_tot["방송회차명"][j])
#         day2.append(drama_tot["방송일자"][j])
#         if temp1[i] == temp2[j] and ct1[i] == ct2[j] and day1[i] > day2[j]:
#             temp3.append(drama_tot["프로그램명"][j])
#             ct3.append(drama_tot["방송회차명"][j])
#             day3.append(drama_tot["방송일자"][j])
#         elif temp1[i] == temp2[j] and ct1[i] == ct2[j] and day1[i] < day2[j]:
#             temp3.append(drama_tot["프로그램명"][i])
#             ct3.append(drama_tot["방송회차명"][i])
#             day3.append(drama_tot["방송일자"][i])

# %%
if temp1[0] == temp2[0] and ct1[0] == ct2[0]:
    print("같은방송 같은회차")
# Out:
# 같은방송 같은회차

# %%
temp3
# Out:
# ['99억의여자',
#  '99억의여자',
#  '하자있는인간들',
#  '싸이코패스다이어리',
#  '99억의여자',
#  '99억의여자',
#  '하자있는인간들',
#  '싸이코패스다이어리',
#  '손THEGUEST',
#  '스토브리그',
#  '스토브리그',
#  '스토브리그',
#  '스토브리그',
#  '스토브리그',
#  '스토브리그',
#  '스토브리그',
#  '스토브리그',
#  '낭만닥터김사부2',
#  '낭만닥터김사부2',
#  '낭만닥터김사부2',
#  '낭만닥터김사부2',
#  '검사내전',
#  '블랙독',
#  '낭만닥터김사부2',
#  '낭만닥터김사부2',
#  '낭만닥터김사부2',
#  '낭만닥터김사부2',
#  '검사내전',
#  '블랙독',
#  '99억의여자',
#  '99억의여자',
#  '하자있는인간들',
#  '싸이코패스다이어리',
#  '99억의여자',
#  '99억의여자',
#  '하자있는인간들',
#  '싸이코패스다이어리',
#  '스토브리그',
#  '스토브리그',
#  '스토브리그',
#  '스토브리그',
#  '스토브리그',
#  '스토브리그',
#  '스토브리그',
#  '스토브리그',
#  '사랑의불시착',
#  '사랑의불시착',
#  '낭만닥터김사부2',
#  '낭만닥터김사부2',
#  '낭만닥터김사부2',
#  '낭만닥터김사부2',
#  '검사내전',
#  '블랙독',
#  '낭만닥터김사부2',
#  '낭만닥터김사부2',
#  '낭만닥터김사부2',
#  '낭만닥터김사부2',
#  '검사내전',
#  '블랙독',
#  '99억의여자',
#  '99억의여자',
#  '하자있는인간들',
#  '99억의여자',
#  '99억의여자',
#  '하자있는인간들',
#  '트랩',
#  '스토브리그',
#  '스토브리그',
#  '스토브리그',
#  '스토브리그',
#  '스토브리그',
#  '스토브리그',
#  '스토브리그',
#  '스토브리그',
#  '스토브리그',
#  '스토브리그',
# ...

# %%
ct3
# Out:
# ['17회',
#  '18회',
#  '22회',
#  '13회',
#  '19회',
#  '20회',
#  '24회',
#  '14회',
#  '1회',
#  '6회',
#  '6회',
#  '6회',
#  '6회',
#  '7회',
#  '7회',
#  '7회',
#  '7회',
#  '1회',
#  '1회',
#  '1회',
#  '1회',
#  '5회',
#  '7회',
#  '2회',
#  '2회',
#  '2회',
#  '2회',
#  '6회',
#  '8회',
#  '21회',
#  '22회',
#  '26회',
#  '15회',
#  '23회',
#  '24회',
#  '28회',
#  '16회',
#  '8회',
#  '8회',
#  '8회',
#  '8회',
#  '9회',
#  '9회',
#  '9회',
#  '9회',
#  '7회',
#  '8회',
#  '3회',
#  '3회',
#  '3회',
#  '3회',
#  '7회',
#  '9회',
#  '4회',
#  '4회',
#  '4회',
#  '4회',
#  '8회',
#  '10회',
#  '25회',
#  '26회',
#  '30회',
#  '27회',
#  '28회',
#  '32회',
#  '1회',
#  '10회',
#  '10회',
#  '10회',
#  '10회',
#  '10회',
#  '10회',
#  '10회',
#  '10회',
#  '10회',
#  '11회',
#  '11회',
#  '11회',
#  '11회',
#  '11회',
#  '11회',
#  '11회',
#  '11회',
#  '11회',
#  '9회',
#  '9회',
#  '10회',
#  '5회',
#  '5회',
#  '5회',
#  '5회',
#  '9회',
#  '11회',
#  '6회',
#  '6회',
#  '6회',
#  '6회',
#  '10회',
#  '12회',
#  '29회',
#  '30회',
#  '2회',
#  '9회',
#  '9회',
#  '31회',
# ...

# %%
day3
# Out:
# [20200101,
#  20200101,
#  20200101,
#  20200101,
#  20200102,
#  20200102,
#  20200102,
#  20200102,
#  20200102,
#  20200103,
#  20200103,
#  20200103,
#  20200103,
#  20200104,
#  20200104,
#  20200104,
#  20200104,
#  20200106,
#  20200106,
#  20200106,
#  20200106,
#  20200106,
#  20200106,
#  20200107,
#  20200107,
#  20200107,
#  20200107,
#  20200107,
#  20200107,
#  20200108,
#  20200108,
#  20200108,
#  20200108,
#  20200109,
#  20200109,
#  20200109,
#  20200109,
#  20200110,
#  20200110,
#  20200110,
#  20200110,
#  20200111,
#  20200111,
#  20200111,
#  20200111,
#  20200111,
#  20200112,
#  20200113,
#  20200113,
#  20200113,
#  20200113,
#  20200113,
#  20200113,
#  20200114,
#  20200114,
#  20200114,
#  20200114,
#  20200114,
#  20200114,
#  20200115,
#  20200115,
#  20200115,
#  20200116,
#  20200116,
#  20200116,
#  20200116,
#  20200117,
#  20200117,
#  20200117,
#  20200117,
#  20200117,
#  20200117,
#  20200117,
#  20200117,
#  20200117,
#  20200118,
# ...

# %%
# # 같은 방송, 같은 회차일시, 최근 방송순만 필터링
# temp1 = []
# temp2 = []
# temp3 = []
# ct1 = []
# ct2 = []
# ct3 = []
# day1 = []
# day2 = []
# day3 = []
# #
# for i in range(0, len(drama_tot)):
#     temp1.append(drama_tot["프로그램명"][i])
#     ct1.append(drama_tot["방송회차명"][i])
#     day1.append(drama_tot["방송일자"][i])
#     for j in range(0, len(drama_tot)):
#         temp2.append(drama_tot["프로그램명"][j])
#         ct2.append(drama_tot["방송회차명"][j])
#         day2.append(drama_tot["방송일자"][j])
#         if temp1[i] == temp2[j] and ct1[i] == ct2[j]:
            
#             temp3.append(drama_tot["프로그램명"][j])
#             ct3.append(drama_tot["방송회차명"][j])
#             day3.append(drama_tot["방송일자"][j])

# %%
min(drama_tot["방송일자"]) in drama_tot[["방송일자"]]
# Out:
# False

# %%
drama_tot[["방송일자"]]
# Out:
#           방송일자
# 0     20200101
# 1     20200101
# 2     20200101
# 3     20200101
# 4     20200102
# ...        ...
# 2090  20211229
# 2091  20211230
# 2092  20211230
# 2093  20211230
# 2094  20211231
#
# [2095 rows x 1 columns]

# %%
drama_name_group = drama_tot.groupby(["방송일자","채널명","프로그램시작시간","프로그램명","출연진내용"]).mean()[["총시청률"]]
drama_name_group
# Out:
#                                                             총시청률
# 방송일자     채널명  프로그램시작시간 프로그램명     출연진내용
# 20200101 KBS2 22       99억의여자    ['조여정', '김강우', '정웅인']  4.715128
#          MBC  21       하자있는인간들   ['오연서', '안재현', '김슬기']  1.505145
#          tvN  21       싸이코패스다이어리 ['윤시윤', '정인선', '박성훈']  1.390483
# 20200102 KBS2 22       99억의여자    ['조여정', '김강우', '정웅인']  3.507931
#          MBC  21       하자있는인간들   ['오연서', '안재현', '김슬기']  1.369284
# ...                                                          ...
# 20211229 tvN  22       멜랑꼴리아     ['임수정', '이도현', '진경']   0.893172
# 20211230 JTBC 22       공작도시      ['수애', '김강우', '김미숙']   1.106242
#          KBS2 21       학교2021    ['김요한', '조이현', '추영우']  0.809039
#          tvN  22       멜랑꼴리아     ['임수정', '이도현', '진경']   1.124338
# 20211231 tvN  22       배드앤크레이지   ['이동욱', '위하준', '한지은']  1.118169
#
# [1827 rows x 1 columns]

# %%
drama_name_group.sort_values("총시청률")
# Out:
#                                                            총시청률
# 방송일자     채널명 프로그램시작시간 프로그램명    출연진내용
# 20210515 OCN 21       다크홀      ['김옥빈', '이준혁', '임원희']   0.075322
# 20210524 OCN 21       다크홀      ['김옥빈', '이준혁', '임원희']   0.085074
# 20210521 OCN 21       다크홀      ['김옥빈', '이준혁', '임원희']   0.092562
# 20210524 OCN 22       다크홀      ['김옥빈', '이준혁', '임원희']   0.117581
# 20210924 OCN 22       홈타운      ['유재명', '한예리', '엄태구']   0.119378
# ...                                                         ...
# 20200216 tvN 21       사랑의불시착   ['현빈', '손예진', '서지혜']   12.928459
# 20201222 SBS 22       펜트하우스    ['이지아', '김소연', '유진']   12.941860
# 20200225 SBS 22       낭만닥터김사부2 ['한석규', '안효섭', '이성경']  12.959044
# 20201221 SBS 22       펜트하우스    ['이지아', '김소연', '유진']   13.143310
# 20210402 SBS 22       펜트하우스2   ['유진', '김소연', '이지아']   14.395862
#
# [1827 rows x 1 columns]

# %%
drama2 = drama_tot.groupby(["프로그램명","채널명","출연진내용"]).mean()[["총시청률"]]
drama2 = drama2.sort_values(by = "총시청률", ascending = False)

# %%
drama2.head(20)
# Out:
#                                             총시청률
# 프로그램명       채널명 출연진내용
# 펜트하우스2      SBS ['유진', '김소연', '이지아']   14.395862
# 펜트하우스3      SBS ['유진', '김소연', '이지아']   10.102991
# 낭만닥터김사부2    SBS ['한석규', '안효섭', '이성경']   9.248760
# 사랑의불시착      tvN ['현빈', '손예진', '서지혜']    8.415946
# 펜트하우스       SBS ['이지아', '김소연', '유진']    7.375106
# 슬기로운의사생활시즌2 tvN ['조정석', '유연석', '정경호']   7.298163
# 모범택시        SBS ['이제훈', '이솜', '김의성']    7.297410
# 빈센조         tvN ['송중기', '전여빈', '옥택연']   7.255623
# 스토브리그       SBS ['남궁민', '박은빈', '오정세']   7.027899
# 원더우먼        SBS ['이하늬', '이하늬', '이상윤']   6.711989
# 철인왕후        tvN ['신혜선', '김정현', '배종옥']   6.669998
# 갯마을차차차      tvN ['신민아', '김선호', '이상이']   5.613597
# 지리산         tvN ['전지현', '주지훈', '성동일']   5.199785
# 슬기로운의사생활    tvN ['조정석', '유연석', '정경호']   4.935116
# 굿캐스팅        SBS ['최강희', '이상엽', '유인영']   4.551870
# 홍천기         SBS ['안효섭', '김유정', '공명']    4.271302
# 더킹영원의군주     SBS ['이민호', '김고은', '우도환']   4.159239
# 하이바이마마      tvN ['김태희', '이규형', '고보결']   4.001575
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns


from matplotlib import font_manager, rc
import platform

plt.rc("font", family = "Malgun Gothic")

# %%
drama2 = drama2.reset_index()
drama2.index = drama2.index + 1
drama2
# Out:
#          프로그램명   채널명                  출연진내용       총시청률
# 1       펜트하우스2   SBS   ['유진', '김소연', '이지아']  14.395862
# 2       펜트하우스3   SBS   ['유진', '김소연', '이지아']  10.102991
# 3     낭만닥터김사부2   SBS  ['한석규', '안효섭', '이성경']   9.248760
# 4       사랑의불시착   tvN   ['현빈', '손예진', '서지혜']   8.415946
# 5        펜트하우스   SBS   ['이지아', '김소연', '유진']   7.375106
# ..         ...   ...                    ...        ...
# 135        다크홀   OCN  ['김옥빈', '이준혁', '임원희']   0.299624
# 136       IDOL  JTBC  ['안희연', '곽시양', '김민규']   0.277662
# 137  손THEGUEST   OCN  ['김동욱', '김재욱', '정은채']   0.233044
# 138         트랩   OCN  ['이서진', '성동일', '임화영']   0.186361
# 139        홈타운   OCN  ['유재명', '한예리', '엄태구']   0.119378
#
# [139 rows x 4 columns]

# %%
# 방송사별 시청률
drama3 = drama_tot.groupby(["채널명"]).mean()[["총시청률"]]
drama3 = drama3.sort_values(by = "총시청률", ascending = False)

# %%
drama3 = drama3.reset_index()

# %%
drama3
# Out:
#     채널명      총시청률
# 0   SBS  5.233545
# 1   tvN  2.787665
# 2  KBS2  1.918742
# 3   MBC  1.740489
# 4  JTBC  1.247324
# 5   OCN  1.147510

# %%
sns.barplot(x= "채널명",y= "총시청률", data= drama3)
# Out:
# <AxesSubplot:xlabel='채널명', ylabel='총시청률'>

# %%
drama2
# Out:
#          프로그램명   채널명                  출연진내용       총시청률
# 1       펜트하우스2   SBS   ['유진', '김소연', '이지아']  14.395862
# 2       펜트하우스3   SBS   ['유진', '김소연', '이지아']  10.102991
# 3     낭만닥터김사부2   SBS  ['한석규', '안효섭', '이성경']   9.248760
# 4       사랑의불시착   tvN   ['현빈', '손예진', '서지혜']   8.415946
# 5        펜트하우스   SBS   ['이지아', '김소연', '유진']   7.375106
# ..         ...   ...                    ...        ...
# 135        다크홀   OCN  ['김옥빈', '이준혁', '임원희']   0.299624
# 136       IDOL  JTBC  ['안희연', '곽시양', '김민규']   0.277662
# 137  손THEGUEST   OCN  ['김동욱', '김재욱', '정은채']   0.233044
# 138         트랩   OCN  ['이서진', '성동일', '임화영']   0.186361
# 139        홈타운   OCN  ['유재명', '한예리', '엄태구']   0.119378
#
# [139 rows x 4 columns]

# %%
# 방송사별 드라마 방송 개수
drama4 = drama2.groupby(["채널명"]).count()
drama4
# Out:
#       프로그램명  출연진내용  총시청률
# 채널명
# JTBC     24     24    24
# KBS2     21     21    21
# MBC      19     19    19
# OCN      12     12    12
# SBS      19     19    19
# tvN      44     44    44

# %%
drama5 = drama2.groupby(["채널명"]).describe()
drama5
# Out:
#       총시청률                                                              \
#      count      mean       std       min       25%       50%       75%
# 채널명
# JTBC  24.0  1.112175  0.622632  0.277662  0.617317  0.993943  1.515786
# KBS2  21.0  2.043249  0.987095  0.865532  1.244357  1.486434  3.052047
# MBC   19.0  1.793532  0.895049  0.580169  1.266739  1.578058  1.960773
# OCN   12.0  0.811968  0.822683  0.119378  0.282979  0.625568  1.071019
# SBS   19.0  5.283899  3.304174  2.136595  2.862915  4.159239  7.162654
# tvN   44.0  2.796801  1.893736  0.538100  1.564537  2.201336  3.322830
#
#
#             max
# 채널명
# JTBC   2.503926
# KBS2   3.675295
# MBC    3.974026
# OCN    3.116931
# SBS   14.395862
# tvN    8.415946

# %%
drama5["채널명"] == "JTBC"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '채널명'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
sns.barplot(x= "채널명",y= "프로그램명", data= drama4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15268/1391253240.py in <module>
# ----> 1 sns.barplot(x= "채널명",y= "프로그램명", data= drama4)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3183                           estimator, ci, n_boot, units, seed,
# ...

# %% [markdown]
# # 종합반응

# %%
# 종합반응 불러오기
df = pd.read_excel("./종합반응DB_2020년01월_2021년01월.xlsx")

# %%
df
# Out:
#          월간            프로그램명   채널명  요일    게시글      댓글  동영상조회(K)    뉴스  동영상
# 0    202001  사랑은 뷰티풀 인생은 원더풀  KBS2  토일   2380   11709   3189577  1123  241
# 1    202001          두 번은 없다   MBC  토일    424    1409    303103   444  155
# 2    202001       싸이코패스 다이어리   tvN  수목   1299    4494    890999   727  177
# 3    202001          사랑의 불시착   tvN  토일  38239  249171  41477138  5955  379
# 4    202001          99억의 여자  KBS2  수목   1567    7483   1118175  3527  203
# ..      ...              ...   ...  ..    ...     ...       ...   ...  ...
# 274  202101          안녕? 나야!  KBS2  수목    104     233      1612   209    2
# 275  202101          달이 뜨는 강  KBS2  월화    125     515      4482   174    2
# 276  202101  시지프스 : the myth  JTBC  수목    180    1116     84424   211    3
# 277  202101              빈센조   tvN  토일    474    2167    488902   563    7
# 278  202101              타임즈   OCN  토일     45      83       478   203    2
#
# [279 rows x 9 columns]

# %%
# 종합반응 불러오기
df2 = pd.read_excel("./종합반응DB_2021년01월_2021년12월.xlsx")

# %%
df["프로그램명"].unique()
# Out:
# array(['사랑은 뷰티풀 인생은 원더풀', '두 번은 없다', '싸이코패스 다이어리', '사랑의 불시착', '99억의 여자',
#        '하자있는 인간들', '드라마 스테이지 2020', '간택 - 여인들의 전쟁', '검사내전', '블랙독', '루왁인간',
#        '낭만닥터 김사부 2', '머니게임', '더 게임:0시를 향하여', '본 대로 말하라', '포레스트', '방법',
#        '하이바이, 마마!', '안녕 드라큘라', '날씨가 좋으면 찾아가겠어요', '아무도 모른다', '메모리스트',
#        '슬기로운 의사생활', '루갈', '그 남자의 기억법', '어쩌다 가족', '365 : 운명을 거스르는 1년',
#        '반의반', '어서와', '한 번 다녀왔습니다', '계약우정', '화양연화 - 삶이 꽃이 되는 순간', '본 어게인',
#        '굿캐스팅', '저녁 같이 드실래요', '영혼수선공', '오 마이 베이비', '외출', '쌍갑포차', '번외수사',
#        '바람과 구름과 비', '꼰대인턴', '야식남녀', '아는 건 별로 없지만 가족입니다', '행복의 진수',
#        '사이코지만 괜찮아', '모범형사', '미쓰리는 알고 있다', '출사표', '그놈이 그놈이다', '우리, 사랑했을까',
#        '트레인', '십시일반', '악의 꽃', '연애는 귀찮지만 외로운 건 싫어!', '비밀의 숲 2',
#        '내가 가장 예뻤을 때', '도도솔솔라라솔', '미씽: 그들이 있었다', '좀비탐정', '브람스를 좋아하세요?',
#        '트웬티 트웬티', '18 어게인', '청춘기록', '사생활', '오! 삼광빌라!', '학교기담',
#        '나의 위험한 아내', '구미호뎐', '스타트업', '써치', '나를 사랑한 스파이', '카이로스', '펜트하우스',
# ...

# %%
df2["프로그램명"].unique()
# Out:
# array(['오! 삼광빌라!', '펜트하우스', '제발 그 남자 만나지 마요', '라이브온', '복수해라', '경이로운 소문',
#        '낮과 밤', '바람피면 죽는다', '여신강림', '철인왕후', '런 온', '암행어사: 조선비밀수사단',
#        '선배, 그 립스틱 바르지 마요', '결혼작사 이혼작곡', '루카 : 더 비기닝', '안녕? 나야!',
#        '달이 뜨는 강', '시지프스 : the myth', '빈센조', '타임즈', '드라마 스테이지 2021',
#        '러브씬넘버#', '마우스', '오케이 광자매', '경로를 이탈하였습니다', '조선구마사', '나빌레라',
#        '오! 주인님', '아이를 찾습니다', '어쩌다 가족', '대박부동산', '로스쿨', '보쌈-운명을 훔치다',
#        '오월의 청춘', '나의 너에게', '어느 날 우리 집 현관으로 멸망이 들어왔다', '마인', '목표가 생겼다',
#        '간 떨어지는 동거', '라켓소년단', '미치지 않고서야', '결혼작사 이혼작곡 시즌2', '멀리서 보면 푸른 봄',
#        '월간 집', '슬기로운 의사생활2', '알고있지만,', '악마판사', '너는 나의 봄', '더 로드 : 1의 비극',
#        '경찰수업', '이벤트를 확인하세요', '갯마을 차차차', '홍천기', '인간실격', '하이클래스', '달리와 감자탕',
#        '홈타운', '신사와 아가씨', '하트가 빛나는 순간', '연모', '너를 닮은 사람', '지리산', '구경이',
#        '키마이라', '멜랑꼴리아', '너의 밤이 되어줄게', 'IDOL (아이돌 : The Coup)', '어사와 조이',
#        '크라임 퍼즐', '학교 2021', '쇼윈도:여왕의 집', '스폰서', '그 해 우리는', '공작도시', '엉클',
# ...

# %%
react_tot = pd.concat([df,df2],axis=0)
react_tot = react_tot.reset_index(drop=True)
react_tot
# Out:
#          월간            프로그램명   채널명  요일    게시글      댓글  동영상조회(K)    뉴스  동영상
# 0    202001  사랑은 뷰티풀 인생은 원더풀  KBS2  토일   2380   11709   3189577  1123  241
# 1    202001          두 번은 없다   MBC  토일    424    1409    303103   444  155
# 2    202001       싸이코패스 다이어리   tvN  수목   1299    4494    890999   727  177
# 3    202001          사랑의 불시착   tvN  토일  38239  249171  41477138  5955  379
# 4    202001          99억의 여자  KBS2  수목   1567    7483   1118175  3527  203
# ..      ...              ...   ...  ..    ...     ...       ...   ...  ...
# 509  202112              불가살   tvN  토일   6075   18046   3018507  2160  229
# 510  202112      꽃 피면 달 생각하고  KBS2  월화   1860    6591    836133  2876  151
# 511  202112            한 사람만  JTBC  월화    613    2362    370355  1999  179
# 512  202112           고스트 닥터   tvN  월화    284    1271    249038   908   33
# 513  202112       마녀식당으로 오세요   tvN  수목     12      11         0     2    0
#
# [514 rows x 9 columns]

# %%
# 종합 DB 최종
react_tot = react_tot.groupby(["프로그램명","채널명"]).mean()
react_tot
# Out:
#                                   월간          게시글            댓글      동영상조회(K)  \
# 프로그램명                 채널명
# 18 어게인                JTBC  202009.5  4656.000000  35535.000000  3.471482e+06
# 365 : 운명을 거스르는 1년     MBC   202004.0  3411.333333  14957.000000  7.575397e+05
# 99억의 여자               KBS2  202001.0  1567.000000   7483.000000  1.118175e+06
# IDOL (아이돌 : The Coup) JTBC  202111.0   334.000000   2312.000000  3.093180e+05
# KBS 드라마 스페셜 2020      KBS2  202011.0   370.333333    895.333333  8.900633e+04
# ...                              ...          ...           ...           ...
# 한 사람만                 JTBC  202111.5   318.000000   1204.500000  1.915450e+05
# 행복의 진수                JTBC  202005.0    43.000000    102.000000  2.348100e+04
# 홈타운                   tvN   202109.0   644.000000   1374.333333  2.799660e+05
# 홍천기                   SBS   202109.0  5172.333333  26260.333333  6.504966e+06
# 화양연화 - 삶이 꽃이 되는 순간    tvN   202004.5  1092.000000   6919.750000  2.307264e+06
#
# ...

# %%
react_tot["총합"] = react_tot["게시글"] / 1000 + react_tot["댓글"] / 1000+ react_tot["동영상조회(K)"]/10000000\
+ react_tot["뉴스"] / 1000 + react_tot["동영상"] /100
react_tot[["총합"]] = react_tot[["총합"]].round(2)
internet = react_tot[["총합"]]
internet
# Out:
#                                총합
# 프로그램명                 채널명
# 18 어게인                JTBC  44.15
# 365 : 운명을 거스르는 1년     MBC   22.71
# 99억의 여자               KBS2  14.72
# IDOL (아이돌 : The Coup) JTBC   5.26
# KBS 드라마 스페셜 2020      KBS2   3.48
# ...                           ...
# 한 사람만                 JTBC   3.49
# 행복의 진수                JTBC   0.71
# 홈타운                   tvN    4.46
# 홍천기                   SBS   37.46
# 화양연화 - 삶이 꽃이 되는 순간    tvN   11.74
#
# [155 rows x 1 columns]

# %%
internet.to_csv('./internet.csv')

# %% [markdown]
# # 드라마 통합 총시청률

# %%
drama2
# Out:
#          프로그램명   채널명                출연진내용       총시청률
# 1       펜트하우스2   SBS   '유진', '김소연', '이지아'  14.395862
# 2       펜트하우스3   SBS   '유진', '김소연', '이지아'  10.102991
# 3     낭만닥터김사부2   SBS  '한석규', '안효섭', '이성경'   9.248760
# 4       사랑의불시착   tvN   '현빈', '손예진', '서지혜'   8.415946
# 5        펜트하우스   SBS   '이지아', '김소연', '유진'   7.375106
# ..         ...   ...                  ...        ...
# 135        다크홀   OCN  '김옥빈', '이준혁', '임원희'   0.299624
# 136       IDOL  JTBC  '안희연', '곽시양', '김민규'   0.277662
# 137  손THEGUEST   OCN  '김동욱', '김재욱', '정은채'   0.233044
# 138         트랩   OCN  '이서진', '성동일', '임화영'   0.186361
# 139        홈타운   OCN  '유재명', '한예리', '엄태구'   0.119378
#
# [139 rows x 4 columns]

# %%
drama2.to_csv('./drama_all.csv')

# %%
drama_list = []
drama_list = drama2["프로그램명"].unique()
drama_list
# Out:
# array(['펜트하우스2', '펜트하우스3', '낭만닥터김사부2', '사랑의불시착', '펜트하우스', '슬기로운의사생활시즌2',
#        '모범택시', '빈센조', '스토브리그', '원더우먼', '철인왕후', '갯마을차차차', '지리산',
#        '슬기로운의사생활', '굿캐스팅', '홍천기', '더킹영원의군주', '하이바이마마', '옷소매붉은끝동', '비밀의숲2',
#        '앨리스', '99억의여자', '검은태양', '마우스', '경찰수업', '편의점샛별이', '청춘기록', '연모',
#        '달이뜨는강', '암행어사조선비밀수사단', '마인', '구미호뎐', '라켓소년단', '여신강림', '악마판사',
#        '경이로운소문', '꽃피면달생각하고', '불가살', '꼰대인턴', '지금헤어지는중입니다', '사이코지만괜찮아',
#        '날아라개천용', '대박부동산', '어느날우리집현관으로멸망이들어왔다', '모범형사', '스타트업', '오월의청춘',
#        '365운명을거스르는1년', '시지프스', '산후조리원', '브람스를좋아하세요', '낮과밤', '로스쿨', '해피니스',
#        '간떨어지는동거', '그해우리는', '보이스시즌4', '방법', '악의꽃', '안녕나야', '더게임0시를향하여',
#        '달리와감자탕', '저녁같이드실래요', '화양연화삶이꽃이되는순간', '그남자의기억법', '블랙독', '18어게인',
#        '하이클래스', '배드앤크레이지', '뫼비우스:검은태양', '싸이코패스다이어리', '메모리스트', '미쓰리는알고있다',
#        '아는건별로없지만가족입니다', '미치지않고서야', '쌍갑포차', '검사내전', '어사와조이', '런온', '나빌레라',
#        '좀비탐정', '내가가장예뻤을때', '나를사랑한스파이', '그놈이그놈이다', '바람피면죽는다', '홈타운',
# ...

# %%
len(drama_list)
# Out:
# 132

# %%
tvN = drama2[drama2["채널명"] == "tvN"]
tvN = tvn.reset_index(drop=True)
tvN
# Out:
#                 프로그램명  채널명                         출연진내용      총시청률
# 0              사랑의불시착  tvN   ['현빈', '손예진', '서지혜', '김정현']  8.415946
# 1         슬기로운의사생활시즌2  tvN  ['조정석', '유연석', '정경호', '김대명']  7.298163
# 2                 빈센조  tvN  ['송중기', '전여빈', '옥택연', '유재명']  7.255623
# 3                철인왕후  tvN  ['신혜선', '김정현', '배종옥', '김태우']  6.669998
# 4              갯마을차차차  tvN  ['신민아', '김선호', '이상이', '김영옥']  5.613597
# 5                 지리산  tvN  ['전지현', '주지훈', '성동일', '오정세']  5.199785
# 6            슬기로운의사생활  tvN  ['조정석', '유연석', '정경호', '김대명']  4.935116
# 7              하이바이마마  tvN  ['김태희', '이규형', '고보결', '서우진']  4.001575
# 8               비밀의숲2  tvN  ['조승우', '배두나', '최무성', '김영재']  3.851298
# 9                 마우스  tvN  ['이승기', '이희준', '박주현', '경수진']  3.529881
# 10               청춘기록  tvN  ['박보검', '박소담', '변우석', '하희라']  3.440612
# 11                 마인  tvN  ['이보영', '김서형', '이현욱', '옥자연']  3.283569
# 12               구미호뎐  tvN   ['이동욱', '조보아', '김범', '김정난']  3.255889
# ...

# %%
tvN.to_csv('./tvN.csv')

# %%
SBS = drama2[drama2["채널명"] == "SBS"]
SBS = SBS.reset_index(drop=True)
SBS
# Out:
#          프로그램명  채널명                출연진내용       총시청률
# 0       펜트하우스2  SBS   '유진', '김소연', '이지아'  14.395862
# 1       펜트하우스3  SBS   '유진', '김소연', '이지아'  10.102991
# 2     낭만닥터김사부2  SBS  '한석규', '안효섭', '이성경'   9.248760
# 3        펜트하우스  SBS   '이지아', '김소연', '유진'   7.375106
# 4         모범택시  SBS   '이제훈', '이솜', '김의성'   7.297410
# 5        스토브리그  SBS  '남궁민', '박은빈', '오정세'   7.027899
# 6         원더우먼  SBS  '이하늬', '이하늬', '이상윤'   6.711989
# 7         굿캐스팅  SBS  '최강희', '이상엽', '유인영'   4.551870
# 8          홍천기  SBS   '안효섭', '김유정', '공명'   4.271302
# 9      더킹영원의군주  SBS  '이민호', '김고은', '우도환'   4.159239
# 10         앨리스  SBS   '김희선', '주원', '김희선'   3.793675
# 11      편의점샛별이  SBS  '지창욱', '김유정', '한선화'   3.496668
# 12       라켓소년단  SBS  '김상경', '오나라', '탕준상'   3.243918
# 13  지금헤어지는중입니다  SBS  '송혜교', '장기용', '최희서'   2.949968
# 14      날아라개천용  SBS  '권상우', '정우성', '김주현'   2.775862
# 15      날아라개천용  SBS  '권상우', '배성우', '김주현'   2.367302
# 16   브람스를좋아하세요  SBS  '박은빈', '김민재', '김성철'   2.246808
# ...

# %%
SBS.to_csv('./SBS.csv')

# %%
KBS2 = drama2[drama2["채널명"] == "KBS2"]
KBS2 = KBS2.reset_index(drop=True)
KBS2
# Out:
#           프로그램명   채널명                출연진내용      총시청률
# 0        99억의여자  KBS2  '조여정', '김강우', '정웅인'  3.675295
# 1          경찰수업  KBS2   '진영', '차태현', '정수정'  3.504784
# 2            연모  KBS2   '박은빈', '로운', '남윤수'  3.430136
# 3         달이뜨는강  KBS2  '김소현', '나인우', '이지훈'  3.400553
# 4   암행어사조선비밀수사단  KBS2  '김명수', '권나라', '이이경'  3.312360
# 5      꽃피면달생각하고  KBS2  '유승호', '이혜리', '변우석'  3.052047
# 6         대박부동산  KBS2  '장나라', '정용화', '강말금'  2.631727
# 7         오월의청춘  KBS2  '이도현', '고민시', '이상이'  2.431261
# 8          안녕나야  KBS2   '최강희', '김영광', '이레'  2.008027
# 9        달리와감자탕  KBS2   '김민재', '박규영', '권율'  1.971057
# 10         좀비탐정  KBS2  '최진혁', '박주현', '권화운'  1.486434
# 11      그놈이그놈이다  KBS2  '황정음', '윤현민', '서지훈'  1.438876
# 12      바람피면죽는다  KBS2   '조여정', '고준', '김영대'  1.434819
# 13      도도솔솔라라솔  KBS2  '고아라', '이재욱', '김주헌'  1.385906
# 14          출사표  KBS2   '나나', '박성훈', '유다인'  1.307094
# 15         계약우정  KBS2  '이신영', '신승호', '김소혜'  1.244357
# 16         본어게인  KBS2  '장기용', '장기용', '진세연'  1.184121
# ...

# %%
KBS2.to_csv('./KBS2.csv')

# %%
MBC = drama2[drama2["채널명"] == "MBC"]
MBC = MBC.reset_index(drop=True)
MBC
# Out:
#             프로그램명  채널명                출연진내용      총시청률
# 0         옷소매붉은끝동  MBC   '이준호', '이세영', '강훈'  3.974026
# 1            검은태양  MBC  '남궁민', '박하선', '김지은'  3.640759
# 2            꼰대인턴  MBC  '박해진', '김응수', '한지은'  2.970060
# 3    365운명을거스르는1년  MBC  '이준혁', '남지현', '김지수'  2.424069
# 4       더게임0시를향하여  MBC  '옥택연', '이연희', '임주환'  1.975277
# 5        저녁같이드실래요  MBC  '송승헌', '서지혜', '이지훈'  1.946270
# 6         그남자의기억법  MBC  '김동욱', '문가영', '윤종훈'  1.894627
# 7       뫼비우스:검은태양  MBC  '박하선', '정문성', '장영남'  1.682561
# 8        미쓰리는알고있다  MBC  '강성연', '조한선', '박신아'  1.590932
# 9         미치지않고서야  MBC  '정재영', '문소리', '이상엽'  1.578058
# 10       내가가장예뻤을때  MBC   '임수향', '지수', '하석진'  1.447975
# 11       나를사랑한스파이  MBC  '문정혁', '유인나', '임주환'  1.439580
# 12        하자있는인간들  MBC  '오연서', '안재현', '김슬기'  1.273727
# 13           카이로스  MBC  '신성록', '이세영', '안보현'  1.271398
# 14         목표가생겼다  MBC  '김환희', '류수영', '김도훈'  1.262080
# 15           십시일반  MBC  '김혜준', '오나라', '김정영'  1.238146
# ...

# %%
KBS2.to_csv('./KBS2.csv')

# %%
JTBC = drama2[drama2["채널명"] == "JTBC"]
JTBC = JTBC.reset_index(drop=True)
JTBC
# Out:
#            프로그램명   채널명                 출연진내용      총시청률
# 0           모범형사  JTBC  '손현주', '장승조', '이엘리야'  2.503926
# 1           시지프스  JTBC   '조승우', '박신혜', '김병철'  2.333670
# 2            로스쿨  JTBC    '김명민', '김범', '류혜영'  2.229031
# 3          18어게인  JTBC   '김하늘', '윤상현', '이도현'  1.811005
# 4           쌍갑포차  JTBC   '황정음', '육성재', '최원영'  1.532028
# 5           검사내전  JTBC   '이선균', '정려원', '이성재'  1.526801
# 6             런온  JTBC    '임시완', '신세경', '수영'  1.512114
# 7    선배그립스틱바르지마요  JTBC    '원진아', '로운', '이현욱'  1.177803
# 8   설강화:SNOWDROP  JTBC    '정해인', '지수', '유인나'  1.154146
# 9           공작도시  JTBC    '수애', '김강우', '김미숙'  1.142675
# 10          인간실격  JTBC   '전도연', '류준열', '박병은'  1.035927
# 11  날씨가좋으면찾아가겠어요  JTBC   '박민영', '서강준', '문정희'  1.032680
# 12       우리사랑했을까  JTBC   '송지효', '손호준', '송종호'  0.955206
# 13           사생활  JTBC    '서현', '고경표', '김효진'  0.917220
# 14        너를닮은사람  JTBC   '고현정', '신현빈', '김재영'  0.907683
# 15           구경이  JTBC   '이영애', '김혜준', '김해숙'  0.861931
# ...

# %%
JTBC.to_csv('./JTBC.csv')

# %%
OCN = drama2[drama2["채널명"] == "OCN"]
OCN = OCN.reset_index(drop=True)
OCN
# Out:
#         프로그램명  채널명                출연진내용      총시청률
# 0      경이로운소문  OCN  '조병규', '유준상', '김세정'  3.116931
# 1        번외수사  OCN  '차태현', '이선빈', '정상훈'  1.130758
# 2          써치  OCN  '장동윤', '정수정', '문정희'  1.090578
# 3    미씽그들이있었다  OCN   '고수', '허준호', '안소희'  1.064500
# 4      본대로말하라  OCN   '장혁', '최수영', '진서연'  0.945739
# 5          루갈  OCN  '최진혁', '박성웅', '조동혁'  0.821089
# 6         트레인  OCN  '윤시윤', '경수진', '신소율'  0.430047
# 7      보이스시즌4  OCN  '송승헌', '이하나', '이규형'  0.305562
# 8         다크홀  OCN  '김옥빈', '이준혁', '임원희'  0.299624
# 9   손THEGUEST  OCN  '김동욱', '김재욱', '정은채'  0.233044
# 10         트랩  OCN  '이서진', '성동일', '임화영'  0.186361
# 11        홈타운  OCN  '유재명', '한예리', '엄태구'  0.119378

# %%
OCN.to_csv('./OCN.csv')

# %%
actor = drama2['출연진내용'].unique()
type(actor)
# Out:
# numpy.ndarray

# %%
a = list(actor)
type(a)
# Out:
# list

# %%
def flatten(lst):
    result =[]
    for item in lst:
        if type(item) == list:
            result += flatten(item)
        else:
            result += [item]
    return result

aa = flatten(a)
print(flatten(aa))
# Out:
# ["['유진', '김소연', '이지아']", "['한석규', '안효섭', '이성경']", "['현빈', '손예진', '서지혜']", "['이지아', '김소연', '유진']", "['조정석', '유연석', '정경호']", "['이제훈', '이솜', '김의성']", "['송중기', '전여빈', '옥택연']", "['남궁민', '박은빈', '오정세']", "['이하늬', '이하늬', '이상윤']", "['신혜선', '김정현', '배종옥']", "['신민아', '김선호', '이상이']", "['전지현', '주지훈', '성동일']", "['최강희', '이상엽', '유인영']", "['안효섭', '김유정', '공명']", "['이민호', '김고은', '우도환']", "['김태희', '이규형', '고보결']", "['이준호', '이세영', '강훈']", "['조승우', '배두나', '최무성']", "['김희선', '주원', '김희선']", "['조여정', '김강우', '정웅인']", "['남궁민', '박하선', '김지은']", "['이승기', '이희준', '박주현']", "['진영', '차태현', '정수정']", "['지창욱', '김유정', '한선화']", "['박보검', '박소담', '변우석']", "['박은빈', '로운', '남윤수']", "['김소현', '나인우', '이지훈']", "['김명수', '권나라', '이이경']", "['이보영', '김서형', '이현욱']", "['이동욱', '조보아', '김범']", "['김상경', '오나라', '탕준상']", "['문가영', '차은우', '황인엽']", "['지성', '김민정', '진영']", "['조병규', '유준상', '김세정']", "['유승호', '이혜리', '변우석']", "['이진욱', '권나라', '이준']", "['박해진', '김응수', '한지은']", "['송혜교', '장기용', '최희서']", "['김수현', '서예지', '오정세']", "['권상우', '정우성', '김주현']", "['장나라', '
# ...

# %%
drama2['출연진내용'][1] =drama2['출연진내용'][1].strip("[")
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_15268/4090907258.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drama2['출연진내용'][1] =drama2['출연진내용'][1].strip("[")

# %%
drama2['출연진내용'][1] = drama2['출연진내용'][1].strip("]")
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_15268/3841256241.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drama2['출연진내용'][1] = drama2['출연진내용'][1].strip("]")

# %%
for i in range(1,len(drama2['출연진내용'])+1):
    drama2['출연진내용'][i] =drama2['출연진내용'][i].strip("[")
    drama2['출연진내용'][i] = drama2['출연진내용'][i].strip("]")
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_15268/2284506244.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drama2['출연진내용'][i] =drama2['출연진내용'][i].strip("[")
# C:\Users\admin\AppData\Local\Temp/ipykernel_15268/2284506244.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drama2['출연진내용'][i] = drama2['출연진내용'][i].strip("]")

# %%
drama2
# Out:
#          프로그램명   채널명                출연진내용       총시청률
# 1       펜트하우스2   SBS   '유진', '김소연', '이지아'  14.395862
# 2       펜트하우스3   SBS   '유진', '김소연', '이지아'  10.102991
# 3     낭만닥터김사부2   SBS  '한석규', '안효섭', '이성경'   9.248760
# 4       사랑의불시착   tvN   '현빈', '손예진', '서지혜'   8.415946
# 5        펜트하우스   SBS   '이지아', '김소연', '유진'   7.375106
# ..         ...   ...                  ...        ...
# 135        다크홀   OCN  '김옥빈', '이준혁', '임원희'   0.299624
# 136       IDOL  JTBC  '안희연', '곽시양', '김민규'   0.277662
# 137  손THEGUEST   OCN  '김동욱', '김재욱', '정은채'   0.233044
# 138         트랩   OCN  '이서진', '성동일', '임화영'   0.186361
# 139        홈타운   OCN  '유재명', '한예리', '엄태구'   0.119378
#
# [139 rows x 4 columns]

# %%
actor = []
actor = drama2["출연진내용"]
actor
# Out:
# 1       '유진', '김소연', '이지아'
# 2       '유진', '김소연', '이지아'
# 3      '한석규', '안효섭', '이성경'
# 4       '현빈', '손예진', '서지혜'
# 5       '이지아', '김소연', '유진'
#               ...
# 135    '김옥빈', '이준혁', '임원희'
# 136    '안희연', '곽시양', '김민규'
# 137    '김동욱', '김재욱', '정은채'
# 138    '이서진', '성동일', '임화영'
# 139    '유재명', '한예리', '엄태구'
# Name: 출연진내용, Length: 139, dtype: object

# %%
def dequote(s):
    """
    If a string has single or double quotes around it, remove them.
    Make sure the pair of quotes match.
    If a matching pair of quotes is not found, return the string unchanged.
    """
    if (s[0] == s[-1]) and s.startswith(("'", '')):
        return s[1:-1]
    return s

# %%
 dequote(actor[1])
# Out:
# "유진', '김소연', '이지아"

# %%
df = pd.read_csv('./브랜드평판_csv/bp201702.csv')
df
# Out:
#    Unnamed: 0 드라마배우    브랜드평판지수
# 0           1   이영애  3,922,324
# 1           2   신민아  3,376,176
# 2           3   남상미  2,340,288
# 3           4    지성  2,304,176
# 4           5   남궁민  2,141,096
# 5           6   윤균상  1,842,316
# 6           7   박형식  1,800,916
# 7           8   송승헌  1,694,484
# 8           9   이하나  1,672,032
# 9          10   박서준  1,663,568

# %%
del df['Unnamed: 0']

# %%
df
# Out:
#   드라마배우    브랜드평판지수
# 0   이영애  3,922,324
# 1   신민아  3,376,176
# 2   남상미  2,340,288
# 3    지성  2,304,176
# 4   남궁민  2,141,096
# 5   윤균상  1,842,316
# 6   박형식  1,800,916
# 7   송승헌  1,694,484
# 8   이하나  1,672,032
# 9   박서준  1,663,568

# %%
df = pd.read_csv('./internet.csv')
# Out:
#                      프로그램명   채널명  인터넷반응점수총합
# 0                   18 어게인  JTBC      44.15
# 1        365 : 운명을 거스르는 1년   MBC      22.71
# 2                   99억의여자  KBS2      14.72
# 3    IDOL (아이돌 : The Coup)  JTBC       5.26
# 4         KBS 드라마 스페셜 2020  KBS2       3.48
# ..                     ...   ...        ...
# 150                  한 사람만  JTBC       3.49
# 151                 행복의 진수  JTBC       0.71
# 152                    홈타운   tvN       4.46
# 153                    홍천기   SBS      37.46
# 154     화양연화 - 삶이 꽃이 되는 순간   tvN      11.74
#
# [155 rows x 3 columns]

# %%
df = pd.read_csv('./종합반응DB시청률_total.csv',encoding = 'cp949', thousands = ',')

# %%
df.head()
# Out:
#        프로그램명       방송시작일      채널  요일   게시글수     댓글수  동영상조회(K)    뉴스  동영상수  \
# 0      스토브리그  2019.12.13     SBS   금  42064  150748     14407  5394   271
# 1     사랑의불시착  2019.12.14     tvN  토일  38239  249171     41477  5955   379
# 2   낭만닥터김사부2  2020.01.06     SBS  월화  14613   73565     11054  7492   331
# 3        블랙독  2019.12.16     tvN  월화   5876   23347      5628  2662   384
# 4  간택-여인들의전쟁  2019.12.14  TVCHOS  토일   2957    9929      2151  2009   161
#
#    가구시청률(%)  ...  10대시청률(%)  20대시청률(%)  30대시청률(%)  40대시청률(%)  50대시청률(%)  \
# 0      12.7  ...        3.2        3.4        4.5       10.7       11.9
# 1      11.5  ...        5.3        3.3        5.1       12.1        9.3
# 2      15.1  ...        4.4        3.0        4.0       11.6       12.7
# 3       4.5  ...        1.0        0.9        1.4        3.8        3.6
# 4       3.7  ...        0.3        0.7        0.5        1.4        2.5
#
#    TVVOD시청자수(K)  PC실시간(K)  PCVOD(K) Mobile실시간(K) MobileVOD(K)
# ...

# %%
react_per = df.groupby(["프로그램명"]).mean()

# %%
react_per
# Out:
#                       게시글수           댓글수     동영상조회(K)           뉴스        동영상수
# 프로그램명
# 18어게인          4656.000000  35535.000000  3471.500000  1889.250000  172.750000
# 365운명을거스르는1년   3411.333333  14957.000000   757.333333  1874.333333  239.333333
# 99억의여자         1567.000000   7483.000000  1118.000000  3527.000000  203.000000
# IDOL            334.000000   2312.000000   309.333333   862.666667  172.333333
# KBS드라마스페셜2020   370.333333    895.333333    89.333333  1377.000000   82.666667
# ...                    ...           ...          ...          ...         ...
# 행복의진수            43.000000    102.000000    23.000000    80.000000   48.000000
# 허쉬             2039.000000   5412.500000   417.500000  1935.750000  138.500000
# 홈타운             644.000000   1374.333333   280.000000   728.666667  168.333333
# 홍천기            5172.333333  26260.333333  6505.000000  3244.333333  213.666667
# 화양연화삶이꽃이되는순간   1092.000000   6919.750000  2307.000000  1793.000000  170.500000
#
# ...

# %%
# 종합반응DB시청률_total.csv가 원본
# 드라마별 인터넷반응률
react_per = react_per.reset_index()
react_per.index = react_per.index + 1
react_per
# Out:
#              프로그램명         게시글수           댓글수     동영상조회(K)           뉴스  \
# 1            18어게인  4656.000000  35535.000000  3471.500000  1889.250000
# 2     365운명을거스르는1년  3411.333333  14957.000000   757.333333  1874.333333
# 3           99억의여자  1567.000000   7483.000000  1118.000000  3527.000000
# 4             IDOL   334.000000   2312.000000   309.333333   862.666667
# 5    KBS드라마스페셜2020   370.333333    895.333333    89.333333  1377.000000
# ..             ...          ...           ...          ...          ...
# 190          행복의진수    43.000000    102.000000    23.000000    80.000000
# 191             허쉬  2039.000000   5412.500000   417.500000  1935.750000
# 192            홈타운   644.000000   1374.333333   280.000000   728.666667
# 193            홍천기  5172.333333  26260.333333  6505.000000  3244.333333
# 194   화양연화삶이꽃이되는순간  1092.000000   6919.750000  2307.000000  1793.000000
#
#            동영상수
# 1    172.750000
# 2    239.333333
# 3    203.000000
# 4    172.333333
# ...

# %%
df = pd.read_csv('./종합반응DB_시청자수_total.csv',encoding = 'cp949', thousands = ',')
df
# Out:
#          프로그램명       방송시작일      채널  요일   게시글수     댓글수  동영상조회(K)    뉴스  동영상수  \
# 0        스토브리그  2019.12.13     SBS   금  42064  150748     14407  5394   271
# 1       사랑의불시착  2019.12.14     tvN  토일  38239  249171     41477  5955   379
# 2     낭만닥터김사부2  2020.01.06     SBS  월화  14613   73565     11054  7492   331
# 3          블랙독  2019.12.16     tvN  월화   5876   23347      5628  2662   384
# 4    간택-여인들의전쟁  2019.12.14  TVCHOS  토일   2957    9929      2151  2009   161
# ..         ...         ...     ...  ..    ...     ...       ...   ...   ...
# 609       트레이서  2022.01.07     MBC   금    202     558        10   445     7
# 610  악의마음을읽는자들  2022.01.14     SBS   금    179     705        55   492    10
# 611      크라임퍼즐  2021.11.01     SKY  월화     46      78         5    57     0
# 612   하트가빛나는순간  2021.09.28    EBS1  월화     27    3210       920    32     0
# 613  마녀식당으로오세요  2022.01.05     tvN  수목     12      11         0     2     0
#
# ...

# %%
react_count2 = df
react_count2 = react_count2[["프로그램명","채널","10대시청자수(K)","20대시청자수(K)", "30대시청자수(K)", "40대시청자수(K)", "50대시청자수(K)"]]
react_count2
# Out:
#          프로그램명      채널 10대시청자수(K) 20대시청자수(K) 30대시청자수(K) 40대시청자수(K) 50대시청자수(K)
# 0        스토브리그     SBS        167        218        304        876        996
# 1       사랑의불시착     tvN        278        211        344        991        776
# 2     낭만닥터김사부2     SBS        231        196        273        954      1,067
# 3          블랙독     tvN         54         60         94        311        305
# 4    간택-여인들의전쟁  TVCHOS         15         48         34        116        210
# ..         ...     ...        ...        ...        ...        ...        ...
# 609       트레이서     MBC          -          -          -          -          -
# 610  악의마음을읽는자들     SBS          -          -          -          -          -
# 611      크라임퍼즐     SKY          -          -          -          -          -
# 612   하트가빛나는순간    EBS1          5          1          6          9          6
# 613  마녀식당으로오세요     tvN          -          -          -          -          -
#
# [614 rows x 7 columns]

# %%
react_count = df.groupby(["프로그램명"]).mean()
react_count
# Out:
#                       게시글수           댓글수     동영상조회(K)           뉴스        동영상수
# 프로그램명
# 18어게인          4656.000000  35535.000000  3471.500000  1889.250000  172.750000
# 365운명을거스르는1년   3411.333333  14957.000000   757.333333  1874.333333  239.333333
# 99억의여자         1567.000000   7483.000000  1118.000000  3527.000000  203.000000
# IDOL            334.000000   2312.000000   309.333333   862.666667  172.333333
# KBS드라마스페셜2020   370.333333    895.333333    89.333333  1377.000000   82.666667
# ...                    ...           ...          ...          ...         ...
# 행복의진수            43.000000    102.000000    23.000000    80.000000   48.000000
# 허쉬             2039.000000   5412.500000   417.500000  1935.750000  138.500000
# 홈타운             644.000000   1374.333333   280.000000   728.666667  168.333333
# 홍천기            5172.333333  26260.333333  6505.000000  3244.333333  213.666667
# 화양연화삶이꽃이되는순간   1092.000000   6919.750000  2307.000000  1793.000000  170.500000
#
# ...

# %%
# 종합반응DB_시청자수_total.csv가 원본
# 드라마별 인터넷반응 시청자수
react_count = react_count.reset_index()
react_count.index = react_count.index + 1
react_count
# Out:
#              프로그램명         게시글수           댓글수     동영상조회(K)           뉴스  \
# 1            18어게인  4656.000000  35535.000000  3471.500000  1889.250000
# 2     365운명을거스르는1년  3411.333333  14957.000000   757.333333  1874.333333
# 3           99억의여자  1567.000000   7483.000000  1118.000000  3527.000000
# 4             IDOL   334.000000   2312.000000   309.333333   862.666667
# 5    KBS드라마스페셜2020   370.333333    895.333333    89.333333  1377.000000
# ..             ...          ...           ...          ...          ...
# 190          행복의진수    43.000000    102.000000    23.000000    80.000000
# 191             허쉬  2039.000000   5412.500000   417.500000  1935.750000
# 192            홈타운   644.000000   1374.333333   280.000000   728.666667
# 193            홍천기  5172.333333  26260.333333  6505.000000  3244.333333
# 194   화양연화삶이꽃이되는순간  1092.000000   6919.750000  2307.000000  1793.000000
#
#            동영상수
# 1    172.750000
# 2    239.333333
# 3    203.000000
# 4    172.333333
# ...

# %%
react_per
# Out:
#              프로그램명         게시글수           댓글수     동영상조회(K)           뉴스  \
# 1            18어게인  4656.000000  35535.000000  3471.500000  1889.250000
# 2     365운명을거스르는1년  3411.333333  14957.000000   757.333333  1874.333333
# 3           99억의여자  1567.000000   7483.000000  1118.000000  3527.000000
# 4             IDOL   334.000000   2312.000000   309.333333   862.666667
# 5    KBS드라마스페셜2020   370.333333    895.333333    89.333333  1377.000000
# ..             ...          ...           ...          ...          ...
# 190          행복의진수    43.000000    102.000000    23.000000    80.000000
# 191             허쉬  2039.000000   5412.500000   417.500000  1935.750000
# 192            홈타운   644.000000   1374.333333   280.000000   728.666667
# 193            홍천기  5172.333333  26260.333333  6505.000000  3244.333333
# 194   화양연화삶이꽃이되는순간  1092.000000   6919.750000  2307.000000  1793.000000
#
#            동영상수
# 1    172.750000
# 2    239.333333
# 3    203.000000
# 4    172.333333
# ...

# %%
react_count = react_count.sort_values(by = "게시글수", ascending = False)
react_count
# Out:
#          프로그램명          게시글수            댓글수      동영상조회(K)           뉴스  \
# 97      사랑의불시착  41127.500000  257462.000000  44437.500000  5749.000000
# 90       부부의세계  37923.666667  262790.000000  36026.333333  7066.666667
# 175      펜트하우스  35886.000000  166134.000000  29736.250000  5855.750000
# 105      스토브리그  33935.500000  125258.000000  11750.000000  4908.500000
# 154     이태원클라쓰  28200.000000  146823.333333  19042.666667  5618.666667
# ..         ...           ...            ...           ...          ...
# 190      행복의진수     43.000000     102.000000     23.000000    80.000000
# 63        루왁인간     41.000000      85.000000      1.000000    46.000000
# 184   하트가빛나는순간     36.500000    4139.500000   1123.000000    67.250000
# 35       나의너에게     26.000000      68.000000      3.000000   117.000000
# 65   마녀식당으로오세요     12.000000      11.000000      0.000000     2.000000
#
#            동영상수
# 97   448.500000
# 90   303.666667
# 175  254.500000
# 105  254.500000
# 154  323.666667
# ...

# %%
react_count = react_count.reset_index(drop = True)
react_count
# Out:
#          프로그램명          게시글수            댓글수      동영상조회(K)           뉴스  \
# 0       사랑의불시착  41127.500000  257462.000000  44437.500000  5749.000000
# 1        부부의세계  37923.666667  262790.000000  36026.333333  7066.666667
# 2        펜트하우스  35886.000000  166134.000000  29736.250000  5855.750000
# 3        스토브리그  33935.500000  125258.000000  11750.000000  4908.500000
# 4       이태원클라쓰  28200.000000  146823.333333  19042.666667  5618.666667
# ..         ...           ...            ...           ...          ...
# 189      행복의진수     43.000000     102.000000     23.000000    80.000000
# 190       루왁인간     41.000000      85.000000      1.000000    46.000000
# 191   하트가빛나는순간     36.500000    4139.500000   1123.000000    67.250000
# 192      나의너에게     26.000000      68.000000      3.000000   117.000000
# 193  마녀식당으로오세요     12.000000      11.000000      0.000000     2.000000
#
#            동영상수
# 0    448.500000
# 1    303.666667
# 2    254.500000
# 3    254.500000
# 4    323.666667
# ...

# %%
df = pd.read_csv('./인터넷반응DB_2020년1월1주_2021년12월5주.csv',encoding = 'cp949', thousands = ',')
df
# Out:
#           주차         프로그램명    채널  요일  게시글(건수)  댓글(건수)  동영상조회(건수)  뉴스(건수)  \
# 0     202001  사랑은뷰티풀인생은원더풀  KBS2  토일      543    2158     735273     192
# 1     202001         두번은없다   MBC  토일      151     363      96398     210
# 2     202001     싸이코패스다이어리   tvN  수목      566    2157     380146     297
# 3     202001        사랑의불시착   tvN  토일     6013   35527    4349077    1072
# 4     202001        99억의여자  KBS2  수목      496    2330     268812    1052
# ...      ...           ...   ...  ..      ...     ...        ...     ...
# 1564  202152           불가살   tvN  토일     1646    5856    1602331     600
# 1565  202152      꽃피면달생각하고  KBS2  월화      586    1972     363172     743
# 1566  202152          한사람만  JTBC  월화      167     702     181759     490
# 1567  202152         고스트닥터   tvN  월화      147     460     121771     384
# 1568  202152     마녀식당으로오세요   tvN  수목       19      24          0       2
#
#       동영상(건수)  게시글(점유율%)  댓글(점유율%)  동영상조회(점유율%)  뉴스(점유율%)  동영상(점유율%)   가구시청자수  \
# ...

# %%
react_week = df.groupby(["프로그램명"]).mean()
react_week
# Out:
#                      주차      게시글(건수)        댓글(건수)     동영상조회(건수)      뉴스(건수)  \
# 프로그램명
# 18어게인          202040.0  1432.615385  10933.846154  1.068148e+06  581.307692
# 365운명을거스르는1년   202014.0  1137.222222   4986.444444  2.525132e+05  624.777778
# 99억의여자         202002.5   415.250000   1991.250000  2.885188e+05  932.000000
# IDOL           202146.0   111.333333    770.666667  1.031060e+05  287.555556
# KBS드라마스페셜2020  202047.0   101.000000    244.181818  2.427445e+04  375.545455
# ...                 ...          ...           ...           ...         ...
# 한사람만           202150.0   131.400000    482.000000  7.661800e+04  418.400000
# 행복의진수          202021.0    43.000000    102.000000  2.348100e+04   80.000000
# 홈타운            202139.0   214.666667    458.111111  9.332200e+04  242.888889
# 홍천기            202137.5  1293.083333   6565.083333  1.626241e+06  811.083333
# 화양연화삶이꽃이되는순간   202018.5   364.000000   2306.583333  7.690882e+05  597.666667
#
# ...

# %%
# /인터넷반응DB_2020년1월1주_2021년12월5주.csv
# 드라마별 인터넷반응 시청자수(주차별에서 합본)
react_week = react_week.reset_index()
react_week.index = react_week.index + 1
react_week
# Out:
#              프로그램명        주차      게시글(건수)        댓글(건수)     동영상조회(건수)  \
# 1            18어게인  202040.0  1432.615385  10933.846154  1.068148e+06
# 2     365운명을거스르는1년  202014.0  1137.222222   4986.444444  2.525132e+05
# 3           99억의여자  202002.5   415.250000   1991.250000  2.885188e+05
# 4             IDOL  202146.0   111.333333    770.666667  1.031060e+05
# 5    KBS드라마스페셜2020  202047.0   101.000000    244.181818  2.427445e+04
# ..             ...       ...          ...           ...           ...
# 151           한사람만  202150.0   131.400000    482.000000  7.661800e+04
# 152          행복의진수  202021.0    43.000000    102.000000  2.348100e+04
# 153            홈타운  202139.0   214.666667    458.111111  9.332200e+04
# 154            홍천기  202137.5  1293.083333   6565.083333  1.626241e+06
# 155   화양연화삶이꽃이되는순간  202018.5   364.000000   2306.583333  7.690882e+05
#
#          뉴스(건수)    동영상(건수)  게시글(점유율%)  댓글(점유율%)  동영상조회(점유율%)  뉴스(점유율%)  \
# ...

# %%
react_week = react_week.sort_values(by = "게시글(건수)", ascending = False)
react_week = react_week.reset_index(drop = True)
react_week
# Out:
#          프로그램명             주차       게시글(건수)        댓글(건수)     동영상조회(건수)  \
# 0       사랑의불시착  202004.000000  12044.142857  75330.285714  1.286952e+07
# 1        펜트하우스  202050.692308   8762.461538  40101.307692  7.788396e+06
# 2     사이코지만괜찮아  202027.000000   6708.272727  33426.181818  3.828093e+06
# 3        비밀의숲2  202035.500000   6550.300000  26575.300000  1.397527e+06
# 4         청춘기록  202039.000000   6278.454545  32736.363636  2.107108e+06
# ..         ...            ...           ...           ...           ...
# 150      행복의진수  202021.000000     43.000000    102.000000  2.348100e+04
# 151      어쩌다가족  202070.136364     34.590909    139.636364  6.740818e+03
# 152  마녀식당으로오세요  202152.000000     19.000000     24.000000  0.000000e+00
# 153      나의너에게  202115.500000     13.000000     34.000000  1.554000e+03
# 154   하트가빛나는순간  202143.500000      9.125000   1034.875000  2.807259e+05
#
#           뉴스(건수)     동영상(건수)  게시글(점유율%)   댓글(점유율%)  동영상조회(점유율%)  뉴스(점유율%)  \
# ...

# %%
react_week = react_week.round(2)
react_week
# Out:
#          프로그램명         주차   게시글(건수)    댓글(건수)    동영상조회(건수)   뉴스(건수)  동영상(건수)  \
# 0       사랑의불시착  202004.00  12044.14  75330.29  12869522.14  1725.29   129.29
# 1        펜트하우스  202050.69   8762.46  40101.31   7788396.00  1584.15    71.38
# 2     사이코지만괜찮아  202027.00   6708.27  33426.18   3828092.91  1050.45   110.09
# 3        비밀의숲2  202035.50   6550.30  26575.30   1397526.70   842.90    95.10
# 4         청춘기록  202039.00   6278.45  32736.36   2107107.64  1024.09    82.00
# ..         ...        ...       ...       ...          ...      ...      ...
# 150      행복의진수  202021.00     43.00    102.00     23481.00    80.00    48.00
# 151      어쩌다가족  202070.14     34.59    139.64      6740.82   208.95     9.64
# 152  마녀식당으로오세요  202152.00     19.00     24.00         0.00     2.00     0.00
# 153      나의너에게  202115.50     13.00     34.00      1554.00    58.50     0.00
# 154   하트가빛나는순간  202143.50      9.12   1034.88    280725.94    16.81     0.06
#
# ...

# %%
react_week.to_csv('./react_week.csv')

# %%
react_week.to_excel('./react_week.xlsx', index = False)

# %%
# react_week.drop(["주차"], axis = 1, inplace = True)

# %%
react_week
# Out:
#          프로그램명   게시글(건수)    댓글(건수)    동영상조회(건수)   뉴스(건수)  동영상(건수)  게시글(점유율%)  \
# 0       사랑의불시착  12044.14  75330.29  12869522.14  1725.29   129.29      16.80
# 1        펜트하우스   8762.46  40101.31   7788396.00  1584.15    71.38      11.43
# 2     사이코지만괜찮아   6708.27  33426.18   3828092.91  1050.45   110.09      10.13
# 3        비밀의숲2   6550.30  26575.30   1397526.70   842.90    95.10      11.00
# 4         청춘기록   6278.45  32736.36   2107107.64  1024.09    82.00       9.07
# ..         ...       ...       ...          ...      ...      ...        ...
# 150      행복의진수     43.00    102.00     23481.00    80.00    48.00       0.00
# 151      어쩌다가족     34.59    139.64      6740.82   208.95     9.64       0.05
# 152  마녀식당으로오세요     19.00     24.00         0.00     2.00     0.00       0.00
# 153      나의너에게     13.00     34.00      1554.00    58.50     0.00       0.05
# 154   하트가빛나는순간      9.12   1034.88    280725.94    16.81     0.06       0.01
#
# ...

# %%
react_count
# Out:
#                       게시글수           댓글수     동영상조회(K)           뉴스        동영상수
# 프로그램명
# 18어게인          4656.000000  35535.000000  3471.500000  1889.250000  172.750000
# 365운명을거스르는1년   3411.333333  14957.000000   757.333333  1874.333333  239.333333
# 99억의여자         1567.000000   7483.000000  1118.000000  3527.000000  203.000000
# IDOL            334.000000   2312.000000   309.333333   862.666667  172.333333
# KBS드라마스페셜2020   370.333333    895.333333    89.333333  1377.000000   82.666667
# ...                    ...           ...          ...          ...         ...
# 행복의진수            43.000000    102.000000    23.000000    80.000000   48.000000
# 허쉬             2039.000000   5412.500000   417.500000  1935.750000  138.500000
# 홈타운             644.000000   1374.333333   280.000000   728.666667  168.333333
# 홍천기            5172.333333  26260.333333  6505.000000  3244.333333  213.666667
# 화양연화삶이꽃이되는순간   1092.000000   6919.750000  2307.000000  1793.000000  170.500000
#
# ...

# %%
react_count.to_excel('./react_count.xlsx', index = False)

# %%
react_week.round(2)
# Out:
#          프로그램명         주차   게시글(건수)    댓글(건수)    동영상조회(건수)   뉴스(건수)  동영상(건수)  \
# 0       사랑의불시착  202004.00  12044.14  75330.29  12869522.14  1725.29   129.29
# 1        펜트하우스  202050.69   8762.46  40101.31   7788396.00  1584.15    71.38
# 2     사이코지만괜찮아  202027.00   6708.27  33426.18   3828092.91  1050.45   110.09
# 3        비밀의숲2  202035.50   6550.30  26575.30   1397526.70   842.90    95.10
# 4         청춘기록  202039.00   6278.45  32736.36   2107107.64  1024.09    82.00
# ..         ...        ...       ...       ...          ...      ...      ...
# 150      행복의진수  202021.00     43.00    102.00     23481.00    80.00    48.00
# 151      어쩌다가족  202070.14     34.59    139.64      6740.82   208.95     9.64
# 152  마녀식당으로오세요  202152.00     19.00     24.00         0.00     2.00     0.00
# 153      나의너에게  202115.50     13.00     34.00      1554.00    58.50     0.00
# 154   하트가빛나는순간  202143.50      9.12   1034.88    280725.94    16.81     0.06
#
# ...

# %%
react_count
# Out:
#              프로그램명         게시글수           댓글수     동영상조회(K)           뉴스  \
# 1            18어게인  4656.000000  35535.000000  3471.500000  1889.250000
# 2     365운명을거스르는1년  3411.333333  14957.000000   757.333333  1874.333333
# 3           99억의여자  1567.000000   7483.000000  1118.000000  3527.000000
# 4             IDOL   334.000000   2312.000000   309.333333   862.666667
# 5    KBS드라마스페셜2020   370.333333    895.333333    89.333333  1377.000000
# ..             ...          ...           ...          ...          ...
# 190          행복의진수    43.000000    102.000000    23.000000    80.000000
# 191             허쉬  2039.000000   5412.500000   417.500000  1935.750000
# 192            홈타운   644.000000   1374.333333   280.000000   728.666667
# 193            홍천기  5172.333333  26260.333333  6505.000000  3244.333333
# 194   화양연화삶이꽃이되는순간  1092.000000   6919.750000  2307.000000  1793.000000
#
#            동영상수
# 1    172.750000
# 2    239.333333
# 3    203.000000
# 4    172.333333
# ...
